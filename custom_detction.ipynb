# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12375, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 12375 (delta 22), reused 14 (delta 6), pack-reused 12335
# Receiving objects: 100% (12375/12375), 12.14 MiB | 377.00 KiB/s, done.
# Resolving deltas: 100% (8533/8533), done.

# %%
# %cd yolov5
# Out:
# /home/sourav/Documents/yolov5 custom training/9rcv8mm682-1/Safety Helmet Wearing Dataset/yolov5

# %%
# !python3 detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source "/home/sourav/Documents/yolov5 custom training/images/train/*.png"
# Out:
# detect: weights=['yolov5s.pt'], source=/home/sourav/Documents/yolov5 custom training/images/train/*.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/home/sourav/Documents/yolov5': No such file or directory
# YOLOv5 🚀 2022-7-2 Python-3.8.10 torch-1.12.0+cu102 CPU
#
# ...
# 100%|███████████████████████████████████████| 14.1M/14.1M [01:07<00:00, 220kB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/4000 /home/sourav/Documents/yolov5 custom training/images/train/hard_hat_workers0.png: 640x640 12 persons, Done. (0.689s)
# ...
